# %% [markdown]
# `-` 설명

# %% [markdown]
# 아래 코드들 중 R과 python은 최소 한번 이상은 등장해야 함 (목록 안에서나 목록별로 모두 허용 : R과 Python 둘로 풀어도 되고, 하나로만 풀어도 된다. 최소한 한두개는 섞어야 한다.)
#
# - 조원 이름
# - 데이터 출처, 테이블 개수 및 샘플수와 변수의 수
# > 행이 몇개고, 열이 몇개인지. 타입이나 기초 통계량도 보여줄 순 있음.
#
# - ER 다이어그램을 위한 요구사항 목록 (문장으로 서술)
# > 요구사항 목록 문장으로 만듦
#
# - ER 다이어그램 (반드시 강의에서 표현한 형식을 이용)
# - 개체와 관계로부터 몇 개의 릴레이션을 구성하는지 서술
# > 몇 개를 구성할 지 써주세요, 글로. 테이블 만들 도형은 색을 다르게 하는 것도 좋아요.
#
# - 각 릴레이션의 속성과 스키마
# - 기본키와 외래키
# > 기본키 설정을 반드시 해주시고, 외래키도 정확히 정리를 해주세요.
# >
# > 기본키가 두 개인 것이 아니라, 차원이 두 개인 겁니다.
#
# - 각 릴레이션의 속성 중 일대일, 일대다 관계로 파생된 속성을 별도 음영으로 구분
# > 원래 있었던 속성은 아닌데 추가적으로 붙은 것들을 구분해주세요.
#
# - 정규화을 위한 함수종속 관계 그림을 각 릴레이션별로 그림
# > 화살표 그림을 그려주세요. 간단하진 않을 수도 있지만, 그 경우는 기본키 중심으로 하면 돼요.
#
# - 정규화 수준을 정하고 몇 개의 릴레이션으로 쪼개지는지 서술
# - 최종 릴레이션의 개수 및 속성 재정리
# > 정규화 이후 정리한 거를 보여주세요.
#
# ---
#
# 조작을 잘 하는지...
#
# 어떻게 하는 게 제일 좋냐면, 코드를 넣었는데 이렇게 나온다라고 하면 됩니다.
#
# - 기본키 설정이 맞는지 확인 (삽입에 대한 정상 및 오류 예제): 코드 및 결과
# > 오류를 일부러 유도하는 것
#
# - 튜플의 수정 및 삭제: 코드 및 결과
# > 튜플이 너무 많으면 해당 부분만 LIMIT과 OFFSET을 이용하여 보여줘야 합니다.
#
# - 기본키 삭제에 따른 외래키의 변화 확인: 코드 및 결과
# > 참조하는 부분
#
# - 조인 조작의 정상상 여부 확인: 코드 및 결과
# > 조인을 얼마나 잘 하는지
#
# - 정보 추출을 위한 주요 변수 및 목표 서술
# > 주요 변수가 뭔지 먼저 말씀을 해주시고요, 관심이 뭔지, 목표는 뭔지
#
# - 주요 변수에 대한 평균과 빈도: sqlite를 이용
# > 주요 속성 몇 개만 정보 추출을 할 건지 해주세요. 연속형이면 평균, 범주형이면 빈도요.
#
# - 정보추출: group by를 비롯한 sql 구문 이용
# > 필요한 정보 추출은 SQL의 GROUP BY문만 사용하여 Conditional Value를 추출하는 것입니다. SQL문만을
#
# - 추출하고자하는 정보를 위해서 조인 및 추출 조작을 통해서 (외부) 데이터 프레임 구성
# > 이건 외부로 데이터프레임을 내보내는 것
#
# - 테이터 프레임을 이용한 데이터 탐색, 시각화 (비지도학습이나 회귀직선까지 허용)
# > 군집분석이나 회귀직선을 그리거나 그런 거 해주세요
#
# 발표자료와 데이터(원천 자료)/데이터베이스 파일/코드는 발표 이후 제출해야 함

# %% [markdown]
# 데이터베이스 구축과 정보추출을 중점적으로 보고 있습니다.
