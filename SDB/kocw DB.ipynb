# %% [markdown]
# Tasks
#
# 1. 제공대학 릴레이션의 소재지 항목 데이터 추가

# %%
len(set(kocw.제공대학명))
## 소재지 시도 데이터 추가법
## trns = {list(set(kocw.제공대학명))[i]:region_list for i in range(len(set(kocw.제공대학명)))}
## kocw.assign(시도 = kocw.제공대학명.map(trns))
# Out:
# 186

# %% [markdown]
# 2. 데이터 테이블 전처리
#
# * 교육 중분류명 NaN값 처리
# * 강의학기 => 강의년도 + 강의학기 처리
# * 중복 교수명 처리 및 담당교수코드 만들기

# %% [markdown]
# 3. E-R 다이어그램 이미지 자료 만들기(ppt)

# %%
import pandas as pd

# %%
kocw = pd.read_excel("./kocw data/kocw_data.xls", header = 1)

# %%
kocw
# Out:
#       교육 대분류명      교육 중분류명       공개강의명  \
# 0        자연계열  수학ㆍ물리ㆍ천문ㆍ지리       대학수학1
# 1        자연계열  수학ㆍ물리ㆍ천문ㆍ지리         수학1
# 2        자연계열  수학ㆍ물리ㆍ천문ㆍ지리        미적분학
# 3        자연계열  수학ㆍ물리ㆍ천문ㆍ지리       공학수학1
# 4        자연계열  수학ㆍ물리ㆍ천문ㆍ지리         정수론
# ...       ...          ...         ...
# 16817    자연계열  수학ㆍ물리ㆍ천문ㆍ지리  다변량통계학(II)
# 16818    자연계열  수학ㆍ물리ㆍ천문ㆍ지리  AI를 위한 딥러닝
# 16819    자연계열  수학ㆍ물리ㆍ천문ㆍ지리    회귀분석(II)
# 16820    자연계열       자연과학기타      과학사 이해
# 16821    자연계열       자연과학기타   예방치과학의 이해
#
#                                                   공개강의설명    제공대학명  교수명  \
# 0      먼저 두 집합 사이에서 함수를 정의하고 이로부터 우리는 그래프를 얻는다. 평면상에서...    한경대학교  안상욱
# 1      자연과학, 공학, 사회과학 등의 다양한 문제들을 수학적으로 모델링하고, 문제의 해결...    가천대학교  이중호
# 2      This course, Calculus, deals with limits, func...    단국대학교  최수한
# 3      공학에서 다루는 기초 및 응용수학을 소개한다. 공학에서 수학의 역할을 이해하고, 응...   성균관대학교  김문현
# 4      이 강의를 통해서 정수론의 기본적인 개념들과 성질들을 익히고, 또한 여러 정수 집합...  덕성여자대학교  이상준
# ...                                                  ...      ...  ...
# 16817                                                NaN    부산대학교  최용석
# 16818  딥러닝 기초를 강의합니다. Tensorflow 와 keras 를 학습합니다. 기본적...    중앙대학교  곽일엽
# 16819                                                NaN    부산대학교  김충락
# 16820  과학사 이해 교과목의 수업 목표는 고대로부터 현대에 이르는 과학의 발전을 넓은 문화...    신라대학교  박종범
# 16821  이 강좌는 예방전문 치과위생사로서 구강병 발생과 예방에 대한 지식과 기술 습득에 필...  울산과학대학교  좌수경
#
#             강의학기        등록일자                                        강의URL주소  \
# 0      2015년 1학기  2015-08-30  http://www.kocw.net/home/cview.do?cid=1095582
# 1      2015년 1학기  2015-09-14  http://www.kocw.net/home/cview.do?cid=1104074
# 2      2015년 1학기  2015-10-08  http://www.kocw.net/home/cview.do?cid=1110603
# 3      2015년 1학기  2015-11-02  http://www.kocw.net/home/cview.do?cid=1112400
# 4      2015년 2학기  2015-12-16  http://www.kocw.net/home/cview.do?cid=1118072
# ...          ...         ...                                            ...
# 16817  2021년 2학기  2022-05-03  http://www.kocw.net/home/cview.do?cid=1430653
# 16818  2022년 1학기  2022-08-17  http://www.kocw.net/home/cview.do?cid=1443736
# 16819  2021년 2학기  2022-09-20  http://www.kocw.net/home/cview.do?cid=1445911
# 16820  2013년 2학기  2013-11-20   http://www.kocw.net/home/cview.do?cid=820840
# 16821  2020년 2학기  2021-06-14  http://www.kocw.net/home/cview.do?cid=1398367
#
#           데이터기준일자   제공기관코드      제공기관명
# 0      2023-11-21  B550629  한국교육학술정보원
# 1      2023-11-21  B550629  한국교육학술정보원
# 2      2023-11-21  B550629  한국교육학술정보원
# 3      2023-11-21  B550629  한국교육학술정보원
# 4      2023-11-21  B550629  한국교육학술정보원
# ...           ...      ...        ...
# 16817  2023-11-21  B550629  한국교육학술정보원
# 16818  2023-11-21  B550629  한국교육학술정보원
# 16819  2023-11-21  B550629  한국교육학술정보원
# 16820  2023-11-21  B550629  한국교육학술정보원
# 16821  2023-11-21  B550629  한국교육학술정보원
#
# [16822 rows x 12 columns]

# %% [markdown]
# `-` 2009년 1학기 ~ 2022년 2학기에 개설된 kocw 강의 데이터 (한국교육학술정보원 2023-11-21 제공)

# %% [markdown]
# ## 데이터 테이블 전처리

# %%
kocw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16822 entries, 0 to 16821
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   교육 대분류명  16822 non-null  object
#  1   교육 중분류명  16814 non-null  object
#  2   공개강의명    16822 non-null  object
#  3   공개강의설명   15498 non-null  object
#  4   제공대학명    16822 non-null  object
#  5   교수명      16822 non-null  object
#  6   강의학기     16822 non-null  object
#  7   등록일자     16822 non-null  object
#  8   강의URL주소  16822 non-null  object
#  9   데이터기준일자  16822 non-null  object
#  10  제공기관코드   16822 non-null  object
#  11  제공기관명    16822 non-null  object
# dtypes: object(12)
# memory usage: 1.5+ MB

# %% [markdown]
# 1. 교육 중분류명이 없는 튜플 제거
#
# 2. 강의코드 인덱스 새기고 테이블 분리
#
# 3. 강의학기 => 강의년도 + 강의학기 처리
#
# 4. 중복된 교수 처리 및 담당교수코드 만들기
#
# 5. 담당 관계에 담당교수코드와 강의코드를 매핑(방법을 좀 생각해봐야 함.)

# %%
## line1 : 교육 중분류명이 없는 튜플 제거
## line2~3 : 강의코드 인덱스를 강의URL주소에서 따오고 정수형으로 변경. 추출된 열은 제거
featured_kocw = kocw.loc[kocw["교육 중분류명"].isna().map(lambda x : False if x else True), :]\
.assign(강의코드 = lambda _df : _df.강의URL주소.str.split("=").str[-1].astype("int"))\
.set_index("강의코드").reset_index().drop("강의URL주소", axis = 1).reset_index(drop = True)
featured_kocw
# Out:
#           강의코드 교육 대분류명      교육 중분류명       공개강의명  \
# 0      1095582    자연계열  수학ㆍ물리ㆍ천문ㆍ지리       대학수학1
# 1      1104074    자연계열  수학ㆍ물리ㆍ천문ㆍ지리         수학1
# 2      1110603    자연계열  수학ㆍ물리ㆍ천문ㆍ지리        미적분학
# 3      1112400    자연계열  수학ㆍ물리ㆍ천문ㆍ지리       공학수학1
# 4      1118072    자연계열  수학ㆍ물리ㆍ천문ㆍ지리         정수론
# ...        ...     ...          ...         ...
# 16809  1430653    자연계열  수학ㆍ물리ㆍ천문ㆍ지리  다변량통계학(II)
# 16810  1443736    자연계열  수학ㆍ물리ㆍ천문ㆍ지리  AI를 위한 딥러닝
# 16811  1445911    자연계열  수학ㆍ물리ㆍ천문ㆍ지리    회귀분석(II)
# 16812   820840    자연계열       자연과학기타      과학사 이해
# 16813  1398367    자연계열       자연과학기타   예방치과학의 이해
#
#                                                   공개강의설명    제공대학명  교수명  \
# 0      먼저 두 집합 사이에서 함수를 정의하고 이로부터 우리는 그래프를 얻는다. 평면상에서...    한경대학교  안상욱
# 1      자연과학, 공학, 사회과학 등의 다양한 문제들을 수학적으로 모델링하고, 문제의 해결...    가천대학교  이중호
# 2      This course, Calculus, deals with limits, func...    단국대학교  최수한
# 3      공학에서 다루는 기초 및 응용수학을 소개한다. 공학에서 수학의 역할을 이해하고, 응...   성균관대학교  김문현
# 4      이 강의를 통해서 정수론의 기본적인 개념들과 성질들을 익히고, 또한 여러 정수 집합...  덕성여자대학교  이상준
# ...                                                  ...      ...  ...
# 16809                                                NaN    부산대학교  최용석
# 16810  딥러닝 기초를 강의합니다. Tensorflow 와 keras 를 학습합니다. 기본적...    중앙대학교  곽일엽
# 16811                                                NaN    부산대학교  김충락
# 16812  과학사 이해 교과목의 수업 목표는 고대로부터 현대에 이르는 과학의 발전을 넓은 문화...    신라대학교  박종범
# 16813  이 강좌는 예방전문 치과위생사로서 구강병 발생과 예방에 대한 지식과 기술 습득에 필...  울산과학대학교  좌수경
#
#             강의학기        등록일자     데이터기준일자   제공기관코드      제공기관명
# 0      2015년 1학기  2015-08-30  2023-11-21  B550629  한국교육학술정보원
# 1      2015년 1학기  2015-09-14  2023-11-21  B550629  한국교육학술정보원
# 2      2015년 1학기  2015-10-08  2023-11-21  B550629  한국교육학술정보원
# 3      2015년 1학기  2015-11-02  2023-11-21  B550629  한국교육학술정보원
# 4      2015년 2학기  2015-12-16  2023-11-21  B550629  한국교육학술정보원
# ...          ...         ...         ...      ...        ...
# 16809  2021년 2학기  2022-05-03  2023-11-21  B550629  한국교육학술정보원
# 16810  2022년 1학기  2022-08-17  2023-11-21  B550629  한국교육학술정보원
# 16811  2021년 2학기  2022-09-20  2023-11-21  B550629  한국교육학술정보원
# 16812  2013년 2학기  2013-11-20  2023-11-21  B550629  한국교육학술정보원
# 16813  2020년 2학기  2021-06-14  2023-11-21  B550629  한국교육학술정보원
#
# [16814 rows x 12 columns]

# %%
## 테이블 분리
professor = featured_kocw[["교수명", "교육 대분류명", "제공대학명", "강의코드"]].rename({"교수명":"담당교수명", "교육 대분류명":"담당분야"}, axis = 1)  ## 담당교수
university = featured_kocw[["제공대학명"]]  ## 제공대학
course = featured_kocw[["강의코드", "공개강의명", "교육 중분류명", "강의학기", "제공대학명"]].rename({"공개강의명":"강의명", "교육 중분류명":"교육분류"}, axis = 1)  ## 강의
charge = featured_kocw[["강의코드", "교수명"]].rename({"교수명":"담당교수명"}, axis = 1)  ## 담당

# %%
## professor 테이블에서 "+"로 구분되는 교수명 행으로 분리, 이후 담당교수명과 담당분야, 제공대학명으로 구성되는 테이블에 대하여 중복되는 값을 없게 하고 인덱스로 담당교수코드 할당.
## {담당교수명, 담당분야, 제공대학명}으로 구성된 데이터와 담당교수코드 두 개의 열로 이뤄진 테이블을 만들고, map({})을 이용하여 담당 관계에 담당교수코드와 강의코드를 매핑
professor
# Out:
#       담당교수명  담당분야    제공대학명     강의코드
# 0       안상욱  자연계열    한경대학교  1095582
# 1       이중호  자연계열    가천대학교  1104074
# 2       최수한  자연계열    단국대학교  1110603
# 3       김문현  자연계열   성균관대학교  1112400
# 4       이상준  자연계열  덕성여자대학교  1118072
# ...     ...   ...      ...      ...
# 16809   최용석  자연계열    부산대학교  1430653
# 16810   곽일엽  자연계열    중앙대학교  1443736
# 16811   김충락  자연계열    부산대학교  1445911
# 16812   박종범  자연계열    신라대학교   820840
# 16813   좌수경  자연계열  울산과학대학교  1398367
#
# [16814 rows x 4 columns]

# %% [markdown]
# 정 힘들 것 같으면 그냥 + 문자열이 들어있는 담당교수명 튜플 없애면 된다.
