# %%
install.packages("aplpack")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(aplpack)

# %%
library(ggplot2)

# %%
ggplot(iris, aes(Species, Sepal.Length)) +
 geom_boxplot(notch = TRUE)
# Out:
# plot without title

# %%
data(iris)

ggplot(iris, aes(Species, Sepal.Length)) +
 geom_violin(width = 0.8, xlab = "")
# Out:
# Warning message in geom_violin(width = 0.8, xlab = ""):
# “Ignoring unknown parameters: `xlab`”
# plot without title

# %%
boxplot(Sepal.Length~Species, data = iris, notch = TRUE)
# Out:
# plot without title
