# %% [markdown]
# # 4. 프로그래밍 구조

# %% [markdown]
# ## 1. 프로그래밍
#
# * 컴퓨터를 이용해 문제를 해결하기 위해 주어진 절차를 문법에 맞게 작성하는 과정
# * 데이터 분석을 진행하다 보면 R에서 제공하는 함수만으로는 해결이 되지 않는 경우가 있으며, 이에 프로그래밍 기법을 활용하면 보다 효율적으로 문제를 해결할 수 있음.

# %% [markdown]
# ## 2. 조건문

# %% [markdown]
# * 조건에 따라 특정한 동작을 실행하도록 하는 프로그래밍 명령어

# %% [markdown]
# ![image.png](attachment:785f36ba-a199-4c9e-a39e-f346ece24b53.png)

# %% [markdown]
# ### A. if문

# %% [markdown]
# * 조건이 참(`TRUE`)이면 코드블록을 실행하고, 거짓(`FALSE`)이면 코드블록을 실행하지 않고 다음 명령문으로 넘어가는 조건문
# * 코드블록 : 중괄호 `{}`로 구분된 코드로, 여러 명령문을 하나로 묶은 실행 단위

# %% [markdown]
# ```
# if (Conditional Statement) {
#     조건이 참일 때 실행할 명령문
# }
# ```
#
# > 약간 C 조건문이랑 스타일이 비슷함.

# %% [markdown]
# ### B. if-else 문

# %% [markdown]
# * 조건이 참이면 첫 번째 코드블록을 실행, 거짓이면 두 번째 코드블록을 실행하는 조건문
# * if-else문에서 else는 반드시 if문의 코드블록을 닫는 `}`와 같은 줄에 작성해야함;;

# %% [markdown]
# ### C. `ifelse` 함수

# %% [markdown]
# * 조건에 따라 두 값 중 하나를 선택하는 경우, ifelse() 함수를 이용하면 편리함
# > SQL, 엑셀 느낌

# %% [markdown]
# ### D. else if 문

# %% [markdown]
# * 첫 번째 조건이 거짓(FALSE)이면 두 번째 조건을 검사하고, 두 번째 조건이 참(TRUE)이면 해당 코드블록을 실행하는 조건문
# * 여러 조건을 순차적으로 검사할 때 사용함
# * 약자로 `elif`를 쓰지 않고, `else if`를 그대로 써줘야 함. `else if`라는 게 따로 있는 게 아니라 그냥 `else`로 분기해 왔을 때, `if`문을 한 번 더 써주는 그런 방식으로 동작하는 듯

# %% [markdown]
# ## 3. 반복문

# %% [markdown]
# * 정해진 동작을 반복적으로 수행할 때 사용하는 프로그래밍 명령어

# %% [markdown]
# ### A. for 문

# %% [markdown]
# * 지정된 횟수만큼 반복하여 코드블록을 실행하는 반복문

# %% [markdown]
# ![image.png](attachment:07413759-629b-4941-86c9-121b3a77a72e.png)

# %% [markdown]
# ```
# for (반복변수 in iterable) {
#     반복내용
# }
# ```

# %% [markdown]
# `-` 예제 : 구구단 2단 출력
#
# * `cat()` 함수 - 한 줄에 여러 개의 값을 결합하여 출력

# %% [markdown]
# ```
# for (i in 1:9) {
#     cat("2 ×", i, '=', 2*i, '\n')
# }
# ```

# %% [markdown]
# $$\underset{i=a}{\overset{n}{\sum}}i = \frac{(n + a)(n-a+1)}{2}$$
#
# > 대충 이런 거였는데. 그냥 a = 1로 치환해서 하는듯

# %% [markdown]
# ### B. while 문

# %% [markdown]
# * 조건이 참(TRUE)일 동안 코드블록을 계속 반복 실행하는 명령문
# * 조건문과 반복문이 결합한 형태임
# > ※ 주의 : 영원히 실행되는 반복문을 ’무한루프(infinite loop)’라 하며, 컴퓨터의 작동을 멈출 수 있음

# %% [markdown]
# ![image.png](attachment:af6c8d29-d481-4d36-92cd-16e1c948e3d3.png)

# %% [markdown]
# ```
# while (Conditional Value) {
#     반복할 명령문
# }
# ```

# %% [markdown]
# ```
# sum <- 0
# i <- 1
#
# while (i <= 100) {
#   sum <- sum + i
#   i <- i + 1
# }
#
# print(sum)
# ```

# %% [markdown]
# > `sum`이 합산하는 함수임에도 불구하고 변수로 할당이 됨. ㅇㅇ;;

# %% [markdown]
# ### C. break문과 next문

# %% [markdown]
# `break`문으로 루프를 강제 종료할 수 있음
#
# `next`문으로 현재 반복을 건너뛰고 다음 반복을 진행함 -> `continue`

# %% [markdown]
# ### D. apply 계열 함수

# %% [markdown]
# 반복적인 작업들을 함수로 적용시키는 것
